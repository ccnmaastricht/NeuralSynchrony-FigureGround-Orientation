# %%
# Add the parent directory of the current working directory to the Python path at runtime. 
# In order to import modules from the src directory.
import os
import sys 

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

from src.stat_utils import *
from src.anl_utils import load_data, get_session_data
from src.plot_utils import colored_heatmap, convert_size

# %%
figsize = [89, 89]
figsize = convert_size(*figsize)
fontsizes = [0, 5, 5, 5]
cmap = "coolwarm"
labels = ['','Contrast heterogeneity', 'Grid coarseness', 'Accuracy']
ticks = [[0.01, 0.25, 0.5, 0.75, 1.0], [1.0, 1.1, 1.2, 1.3, 1.4, 1.5]]
bounds = [0.5, 1.0]

# %%
BASE_PATH = '../results/figures/suppl_one/'
os.makedirs(BASE_PATH, exist_ok=True)
individual_bats = np.load('../results/empirical/session_1/individual_bats.npy')
num_subjects = individual_bats.shape[0]
panel_labels = [chr(i) for i in range(ord('a'), ord('a') + num_subjects)]

# %%
# Create figures of behaviour Arnold tongues per participant
for bat, label in zip(individual_bats, panel_labels):
    filename = os.path.join(BASE_PATH, f'panel_{label}')

    colored_heatmap(bat,
                    figsize=figsize,
                    labels=labels,
                    fontsizes=fontsizes,
                    ticks=ticks,
                    bounds=bounds,
                    colormap=cmap,
                    filename=filename)

# %%
data_path = '../data/Experiment.csv'
data = load_data(data_path)

# Ignore transfer (final) session
data = data[data['SessionID'] != 9]

# %%
# Fit first session model
first_session_data = get_session_data(data, 1)

# List of subjects
subjects = first_session_data['SubjectID'].unique()

# Dictionary to store results
results_session_1 = {}

for subject in subjects:
    subject_data = first_session_data[first_session_data['SubjectID'] == subject]
    model = smf.logit("Correct ~ ContrastHeterogeneity + GridCoarseness + ContrastHeterogeneity*GridCoarseness", subject_data)
    results = model.fit()
    results_session_1[subject] = results.summary()

# Print results for each subject
for subject, result in results_session_1.items():
    print(f"Results for Subject {subject}:\n{result}\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.594022
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.642950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.474849
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.692551
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.567036
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602349
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528991
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.632319
#          Iterations 5
# Results for Subject 1:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                 0.07461
# Time:                        16:34:13   Log-Likelihood:                -445.52
# converged:                       True   LL-Null:                       -481.44
# Covariance Type:            nonrobust   LLR p-value:                 1.721e-15
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                5.8059      1.212      4.791      0.000       3.431       8.181
# ContrastHeterogeneity                   -8.2651      1.802     -4.586      0.000     -11.798      -4.733
# GridCoarseness                          -3.3167      0.929     -3.571      0.000      -5.137      -1.496
# ContrastHeterogeneity:GridCoarseness     5.1553      1.394      3.698      0.000       2.423       7.888
# ========================================================================================================
#
# Results for Subject 2:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                 0.04836
# Time:                        16:34:13   Log-Likelihood:                -482.21
# converged:                       True   LL-Null:                       -506.72
# Covariance Type:            nonrobust   LLR p-value:                 1.299e-10
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                4.7249      1.067      4.430      0.000       2.634       6.815
# ContrastHeterogeneity                   -4.4525      1.642     -2.711      0.007      -7.671      -1.234
# GridCoarseness                          -2.9304      0.826     -3.549      0.000      -4.549      -1.312
# ContrastHeterogeneity:GridCoarseness     2.5351      1.282      1.977      0.048       0.022       5.048
# ========================================================================================================
#
# Results for Subject 3:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1849
# Time:                        16:34:13   Log-Likelihood:                -356.14
# converged:                       True   LL-Null:                       -436.95
# Covariance Type:            nonrobust   LLR p-value:                 8.203e-35
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               12.3338      1.905      6.473      0.000       8.599      16.068
# ContrastHeterogeneity                  -14.9449      2.498     -5.982      0.000     -19.841     -10.049
# GridCoarseness                          -7.3202      1.395     -5.249      0.000     -10.054      -4.587
# ContrastHeterogeneity:GridCoarseness     9.1465      1.856      4.928      0.000       5.509      12.784
# ========================================================================================================
#
# Results for Subject 4:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:               0.0004445
# Time:                        16:34:13   Log-Likelihood:                -519.41
# converged:                       True   LL-Null:                       -519.64
# Covariance Type:            nonrobust   LLR p-value:                    0.9272
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.4034      0.917      0.440      0.660      -1.394       2.201
# ContrastHeterogeneity                   -0.7562      1.492     -0.507      0.612      -3.681       2.169
# GridCoarseness                          -0.2407      0.726     -0.331      0.740      -1.664       1.183
# ContrastHeterogeneity:GridCoarseness     0.5186      1.182      0.439      0.661      -1.798       2.835
# ========================================================================================================
#
# Results for Subject 5:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1039
# Time:                        16:34:13   Log-Likelihood:                -425.28
# converged:                       True   LL-Null:                       -474.56
# Covariance Type:            nonrobust   LLR p-value:                 3.145e-21
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                5.9959      1.317      4.552      0.000       3.414       8.578
# ContrastHeterogeneity                   -5.3921      1.892     -2.851      0.004      -9.100      -1.685
# GridCoarseness                          -3.2089      1.004     -3.195      0.001      -5.177      -1.241
# ContrastHeterogeneity:GridCoarseness     2.5153      1.460      1.723      0.085      -0.346       5.377
# ========================================================================================================
#
# Results for Subject 6:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                 0.07372
# Time:                        16:34:13   Log-Likelihood:                -451.76
# converged:                       True   LL-Null:                       -487.72
# Covariance Type:            nonrobust   LLR p-value:                 1.665e-15
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                7.9851      1.238      6.451      0.000       5.559      10.411
# ContrastHeterogeneity                   -8.1642      1.804     -4.526      0.000     -11.699      -4.629
# GridCoarseness                          -5.2339      0.937     -5.585      0.000      -7.071      -3.397
# ContrastHeterogeneity:GridCoarseness     5.3496      1.385      3.863      0.000       2.635       8.064
# ========================================================================================================
#
# Results for Subject 7:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1060
# Time:                        16:34:13   Log-Likelihood:                -396.74
# converged:                       True   LL-Null:                       -443.77
# Covariance Type:            nonrobust   LLR p-value:                 2.957e-20
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                6.6432      1.459      4.554      0.000       3.784       9.502
# ContrastHeterogeneity                   -6.6811      2.025     -3.300      0.001     -10.650      -2.713
# GridCoarseness                          -3.4489      1.107     -3.117      0.002      -5.618      -1.280
# ContrastHeterogeneity:GridCoarseness     3.4398      1.555      2.213      0.027       0.393       6.487
# ========================================================================================================
#
# Results for Subject 8:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      746
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                 0.04494
# Time:                        16:34:13   Log-Likelihood:                -474.24
# converged:                       True   LL-Null:                       -496.55
# Covariance Type:            nonrobust   LLR p-value:                 1.109e-09
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                5.6933      1.106      5.149      0.000       3.526       7.860
# ContrastHeterogeneity                   -6.1302      1.677     -3.656      0.000      -9.417      -2.844
# GridCoarseness                          -3.6459      0.851     -4.285      0.000      -5.313      -1.978
# ContrastHeterogeneity:GridCoarseness     3.9801      1.303      3.054      0.002       1.426       6.534
# ========================================================================================================

# %%
# Dictionary to store results for all sessions
results_all_sessions = {}

for subject in subjects:
    subject_data = data[data['SubjectID'] == subject]
    model = smf.logit("Correct ~ ContrastHeterogeneity + GridCoarseness + SessionID + SessionID*ContrastHeterogeneity + SessionID*GridCoarseness + ContrastHeterogeneity*GridCoarseness", subject_data)
    results = model.fit()
    results_all_sessions[subject] = results.summary()

# Print results for each subject
for subject, result in results_all_sessions.items():
    print(f"Results for Subject {subject} across all sessions:\n{result}\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.477740
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.522092
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.491895
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.657032
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.459324
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.532986
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.458196
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.504844
#          Iterations 7
# Results for Subject 1 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1706
# Time:                        16:34:14   Log-Likelihood:                -2866.4
# converged:                       True   LL-Null:                       -3456.0
# Covariance Type:            nonrobust   LLR p-value:                1.586e-251
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                6.9620      0.741      9.389      0.000       5.509       8.415
# ContrastHeterogeneity                   -8.7428      0.843    -10.377      0.000     -10.394      -7.092
# GridCoarseness                          -4.0060      0.549     -7.295      0.000      -5.082      -2.930
# SessionID                                0.4494      0.117      3.839      0.000       0.220       0.679
# SessionID:ContrastHeterogeneity         -0.2462      0.048     -5.161      0.000      -0.340      -0.153
# SessionID:GridCoarseness                -0.1619      0.083     -1.953      0.051      -0.324       0.001
# ContrastHeterogeneity:GridCoarseness     5.2326      0.629      8.320      0.000       4.000       6.465
# ========================================================================================================
#
# Results for Subject 2 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1277
# Time:                        16:34:14   Log-Likelihood:                -3132.5
# converged:                       True   LL-Null:                       -3591.2
# Covariance Type:            nonrobust   LLR p-value:                6.918e-195
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                4.7809      0.623      7.668      0.000       3.559       6.003
# ContrastHeterogeneity                   -5.2738      0.735     -7.174      0.000      -6.715      -3.833
# GridCoarseness                          -3.1029      0.471     -6.585      0.000      -4.026      -2.179
# SessionID                                0.3988      0.108      3.685      0.000       0.187       0.611
# SessionID:ContrastHeterogeneity         -0.3525      0.043     -8.111      0.000      -0.438      -0.267
# SessionID:GridCoarseness                -0.0409      0.079     -0.519      0.604      -0.195       0.114
# ContrastHeterogeneity:GridCoarseness     3.4124      0.557      6.122      0.000       2.320       4.505
# ========================================================================================================
#
# Results for Subject 3 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1478
# Time:                        16:34:14   Log-Likelihood:                -2951.4
# converged:                       True   LL-Null:                       -3463.2
# Covariance Type:            nonrobust   LLR p-value:                6.841e-218
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                6.9973      0.749      9.339      0.000       5.529       8.466
# ContrastHeterogeneity                   -8.1333      0.811    -10.024      0.000      -9.724      -6.543
# GridCoarseness                          -3.6359      0.556     -6.537      0.000      -4.726      -2.546
# SessionID                                0.1412      0.112      1.263      0.207      -0.078       0.360
# SessionID:ContrastHeterogeneity         -0.0950      0.046     -2.079      0.038      -0.185      -0.005
# SessionID:GridCoarseness                -0.0472      0.080     -0.587      0.557      -0.205       0.110
# ContrastHeterogeneity:GridCoarseness     4.4440      0.603      7.369      0.000       3.262       5.626
# ========================================================================================================
#
# Results for Subject 4 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                 0.03732
# Time:                        16:34:14   Log-Likelihood:                -3942.2
# converged:                       True   LL-Null:                       -4095.0
# Covariance Type:            nonrobust   LLR p-value:                 5.128e-63
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                3.1251      0.514      6.081      0.000       2.118       4.132
# ContrastHeterogeneity                   -4.6563      0.580     -8.032      0.000      -5.792      -3.520
# GridCoarseness                          -2.5366      0.400     -6.346      0.000      -3.320      -1.753
# SessionID                                0.3601      0.088      4.072      0.000       0.187       0.533
# SessionID:ContrastHeterogeneity         -0.2012      0.034     -5.899      0.000      -0.268      -0.134
# SessionID:GridCoarseness                -0.1481      0.067     -2.209      0.027      -0.280      -0.017
# ContrastHeterogeneity:GridCoarseness     3.7832      0.445      8.508      0.000       2.912       4.655
# ========================================================================================================
#
# Results for Subject 5 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1756
# Time:                        16:34:14   Log-Likelihood:                -2755.9
# converged:                       True   LL-Null:                       -3342.9
# Covariance Type:            nonrobust   LLR p-value:                2.122e-250
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                4.7864      0.740      6.471      0.000       3.337       6.236
# ContrastHeterogeneity                   -4.7236      0.854     -5.534      0.000      -6.397      -3.051
# GridCoarseness                          -2.3223      0.557     -4.171      0.000      -3.413      -1.231
# SessionID                                0.3974      0.117      3.398      0.001       0.168       0.627
# SessionID:ContrastHeterogeneity         -0.3322      0.050     -6.623      0.000      -0.430      -0.234
# SessionID:GridCoarseness                -0.0793      0.084     -0.943      0.346      -0.244       0.086
# ContrastHeterogeneity:GridCoarseness     2.2494      0.645      3.488      0.000       0.986       3.513
# ========================================================================================================
#
# Results for Subject 6 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1283
# Time:                        16:34:14   Log-Likelihood:                -3197.9
# converged:                       True   LL-Null:                       -3668.6
# Covariance Type:            nonrobust   LLR p-value:                4.403e-200
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                8.8209      0.697     12.647      0.000       7.454      10.188
# ContrastHeterogeneity                  -10.3123      0.760    -13.564      0.000     -11.802      -8.822
# GridCoarseness                          -5.6036      0.513    -10.928      0.000      -6.609      -4.599
# SessionID                                0.1584      0.109      1.451      0.147      -0.056       0.372
# SessionID:ContrastHeterogeneity         -0.1201      0.042     -2.870      0.004      -0.202      -0.038
# SessionID:GridCoarseness                -0.0259      0.078     -0.333      0.739      -0.179       0.127
# ContrastHeterogeneity:GridCoarseness     6.6130      0.562     11.757      0.000       5.511       7.715
# ========================================================================================================
#
# Results for Subject 7 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1642
# Time:                        16:34:14   Log-Likelihood:                -2749.2
# converged:                       True   LL-Null:                       -3289.1
# Covariance Type:            nonrobust   LLR p-value:                4.842e-230
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                8.5048      0.804     10.579      0.000       6.929      10.080
# ContrastHeterogeneity                   -8.1452      0.883     -9.227      0.000      -9.875      -6.415
# GridCoarseness                          -5.0027      0.588     -8.512      0.000      -6.155      -3.851
# SessionID                                0.0899      0.120      0.751      0.452      -0.145       0.324
# SessionID:ContrastHeterogeneity         -0.2585      0.049     -5.246      0.000      -0.355      -0.162
# SessionID:GridCoarseness                 0.0962      0.085      1.138      0.255      -0.070       0.262
# ContrastHeterogeneity:GridCoarseness     4.8280      0.651      7.418      0.000       3.552       6.104
# ========================================================================================================
#
# Results for Subject 8 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5993
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 17 Jul 2024   Pseudo R-squ.:                  0.1442
# Time:                        16:34:14   Log-Likelihood:                -3029.1
# converged:                       True   LL-Null:                       -3539.6
# Covariance Type:            nonrobust   LLR p-value:                2.414e-217
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                7.3376      0.700     10.475      0.000       5.965       8.710
# ContrastHeterogeneity                   -7.5709      0.788     -9.612      0.000      -9.115      -6.027
# GridCoarseness                          -4.5748      0.519     -8.817      0.000      -5.592      -3.558
# SessionID                                0.1329      0.111      1.198      0.231      -0.084       0.350
# SessionID:ContrastHeterogeneity         -0.2842      0.045     -6.345      0.000      -0.372      -0.196
# SessionID:GridCoarseness                 0.0854      0.080      1.070      0.285      -0.071       0.242
# ContrastHeterogeneity:GridCoarseness     4.7628      0.587      8.117      0.000       3.613       5.913
# ========================================================================================================
