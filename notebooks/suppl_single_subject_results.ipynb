# %%
# Add the parent directory of the current working directory to the Python path at runtime. 
# In order to import modules from the src directory.
import os
import sys 

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

from src.stat_utils import *
from src.anl_utils import load_data, get_session_data
from src.plot_utils import colored_heatmap, convert_size

# %%
figsize = [89, 89]
figsize = convert_size(*figsize)
fontsizes = [0, 5, 5, 5]
cmap = "coolwarm"
labels = ['','Contrast heterogeneity', 'Grid coarseness', 'Accuracy']
ticks = [[0.01, 0.25, 0.5, 0.75, 1.0], [1.0, 1.1, 1.2, 1.3, 1.4, 1.5]]
bounds = [0.5, 1.0]

# %%
BASE_PATH = '../results/figures/suppl_one/'
os.makedirs(BASE_PATH, exist_ok=True)
individual_bats = np.load('../results/empirical/session_1/individual_bats.npy')
num_subjects = individual_bats.shape[0]
panel_labels = [chr(i) for i in range(ord('a'), ord('a') + num_subjects)]

# %%
# Create figures of behaviour Arnold tongues per participant
for bat, label in zip(individual_bats, panel_labels):
    filename = os.path.join(BASE_PATH, f'panel_{label}')

    colored_heatmap(bat,
                    figsize=figsize,
                    labels=labels,
                    fontsizes=fontsizes,
                    ticks=ticks,
                    bounds=bounds,
                    colormap=cmap,
                    filename=filename)

# %%
data_path = '../data/Experiment.csv'
data = load_data(data_path)

# Ignore transfer (final) session
data = data[data['SessionID'] != 9]

# %%
# Fit first session model
first_session_data = get_session_data(data, 1)

# List of subjects
subjects = first_session_data['SubjectID'].unique()

# Dictionary to store results
results_session_1 = {}

for subject in subjects:
    subject_data = first_session_data[first_session_data['SubjectID'] == subject]
    model = smf.logit("Correct ~ ContrastHeterogeneity + GridCoarseness", subject_data)
    results = model.fit()
    results_session_1[subject] = results.summary()

# Print results for each subject
for subject, result in results_session_1.items():
    print(f"Results for Subject {subject}:\n{result}\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.603442
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645580
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.492515
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.692680
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.569034
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.612684
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.532310
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.638674
#          Iterations 5
# Results for Subject 1:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                 0.05994
# Time:                        11:46:12   Log-Likelihood:                -452.58
# converged:                       True   LL-Null:                       -481.44
# Covariance Type:            nonrobust   LLR p-value:                 2.940e-13
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.0384      0.592      3.446      0.001       0.879       3.198
# ContrastHeterogeneity    -1.7312      0.238     -7.267      0.000      -2.198      -1.264
# GridCoarseness           -0.3591      0.453     -0.792      0.428      -1.248       0.529
# =========================================================================================
#
# Results for Subject 2:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                 0.04447
# Time:                        11:46:12   Log-Likelihood:                -484.19
# converged:                       True   LL-Null:                       -506.72
# Covariance Type:            nonrobust   LLR p-value:                 1.639e-10
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.9868      0.574      5.204      0.000       1.862       4.112
# ContrastHeterogeneity    -1.2484      0.223     -5.594      0.000      -1.686      -0.811
# GridCoarseness           -1.5635      0.437     -3.579      0.000      -2.420      -0.707
# =========================================================================================
#
# Results for Subject 3:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1546
# Time:                        11:46:12   Log-Likelihood:                -369.39
# converged:                       True   LL-Null:                       -436.95
# Covariance Type:            nonrobust   LLR p-value:                 4.562e-30
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.2178      0.697      6.048      0.000       2.851       5.585
# ContrastHeterogeneity    -3.0357      0.298    -10.191      0.000      -3.619      -2.452
# GridCoarseness           -1.1471      0.515     -2.226      0.026      -2.157      -0.137
# =========================================================================================
#
# Results for Subject 4:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:               0.0002591
# Time:                        11:46:12   Log-Likelihood:                -519.51
# converged:                       True   LL-Null:                       -519.64
# Covariance Type:            nonrobust   LLR p-value:                    0.8740
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0758      0.532      0.142      0.887      -0.968       1.119
# ContrastHeterogeneity    -0.1078      0.209     -0.516      0.606      -0.517       0.302
# GridCoarseness            0.0214      0.413      0.052      0.959      -0.789       0.831
# =========================================================================================
#
# Results for Subject 5:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1007
# Time:                        11:46:12   Log-Likelihood:                -426.78
# converged:                       True   LL-Null:                       -474.56
# Covariance Type:            nonrobust   LLR p-value:                 1.760e-21
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.0589      0.637      6.368      0.000       2.810       5.308
# ContrastHeterogeneity    -2.1831      0.254     -8.611      0.000      -2.680      -1.686
# GridCoarseness           -1.7033      0.475     -3.584      0.000      -2.635      -0.772
# =========================================================================================
#
# Results for Subject 6:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                 0.05783
# Time:                        11:46:12   Log-Likelihood:                -459.51
# converged:                       True   LL-Null:                       -487.72
# Covariance Type:            nonrobust   LLR p-value:                 5.647e-13
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 4.0506      0.607      6.676      0.000       2.861       5.240
# ContrastHeterogeneity    -1.3145      0.232     -5.666      0.000      -1.769      -0.860
# GridCoarseness           -2.1903      0.456     -4.801      0.000      -3.084      -1.296
# =========================================================================================
#
# Results for Subject 7:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1004
# Time:                        11:46:12   Log-Likelihood:                -399.23
# converged:                       True   LL-Null:                       -443.77
# Covariance Type:            nonrobust   LLR p-value:                 4.558e-20
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 3.8590      0.661      5.835      0.000       2.563       5.155
# ContrastHeterogeneity    -2.2812      0.268     -8.499      0.000      -2.807      -1.755
# GridCoarseness           -1.2881      0.493     -2.610      0.009      -2.255      -0.321
# =========================================================================================
#
# Results for Subject 8:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                  750
# Model:                          Logit   Df Residuals:                      747
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                 0.03534
# Time:                        11:46:12   Log-Likelihood:                -479.01
# converged:                       True   LL-Null:                       -496.55
# Covariance Type:            nonrobust   LLR p-value:                 2.392e-08
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 2.9158      0.578      5.048      0.000       1.784       4.048
# ContrastHeterogeneity    -1.0828      0.224     -4.836      0.000      -1.522      -0.644
# GridCoarseness           -1.4695      0.440     -3.341      0.001      -2.331      -0.608
# =========================================================================================

# %%
# Dictionary to store results for all sessions
results_all_sessions = {}

for subject in subjects:
    subject_data = data[data['SubjectID'] == subject]
    model = smf.logit("Correct ~ ContrastHeterogeneity + GridCoarseness + SessionID + SessionID*ContrastHeterogeneity + SessionID*GridCoarseness", subject_data)
    results = model.fit()
    results_all_sessions[subject] = results.summary()

# Print results for each subject
for subject, result in results_all_sessions.items():
    print(f"Results for Subject {subject} across all sessions:\n{result}\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.483702
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.525264
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496531
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.663184
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.460346
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.545143
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462915
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.510490
#          Iterations 6
# Results for Subject 1 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1602
# Time:                        11:48:43   Log-Likelihood:                -2902.2
# converged:                       True   LL-Null:                       -3456.0
# Covariance Type:            nonrobust   LLR p-value:                3.070e-237
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           2.9460      0.520      5.670      0.000       1.928       3.964
# ContrastHeterogeneity              -2.0632      0.217     -9.528      0.000      -2.488      -1.639
# GridCoarseness                     -0.8817      0.388     -2.274      0.023      -1.641      -0.122
# SessionID                           0.3215      0.109      2.939      0.003       0.107       0.536
# SessionID:ContrastHeterogeneity    -0.2326      0.047     -4.933      0.000      -0.325      -0.140
# SessionID:GridCoarseness           -0.0704      0.081     -0.874      0.382      -0.228       0.087
# ===================================================================================================
#
# Results for Subject 2 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1224
# Time:                        11:48:43   Log-Likelihood:                -3151.6
# converged:                       True   LL-Null:                       -3591.2
# Covariance Type:            nonrobust   LLR p-value:                8.437e-188
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           2.5030      0.481      5.208      0.000       1.561       3.445
# ContrastHeterogeneity              -0.9532      0.192     -4.971      0.000      -1.329      -0.577
# GridCoarseness                     -1.3144      0.363     -3.620      0.000      -2.026      -0.603
# SessionID                           0.2842      0.103      2.757      0.006       0.082       0.486
# SessionID:ContrastHeterogeneity    -0.3450      0.043     -8.003      0.000      -0.429      -0.260
# SessionID:GridCoarseness            0.0450      0.077      0.585      0.559      -0.106       0.196
# ===================================================================================================
#
# Results for Subject 3 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1398
# Time:                        11:48:43   Log-Likelihood:                -2979.2
# converged:                       True   LL-Null:                       -3463.2
# Covariance Type:            nonrobust   LLR p-value:                5.024e-207
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           3.3674      0.526      6.397      0.000       2.336       4.399
# ContrastHeterogeneity              -2.4575      0.222    -11.082      0.000      -2.892      -2.023
# GridCoarseness                     -0.8121      0.393     -2.065      0.039      -1.583      -0.041
# SessionID                           0.1056      0.106      0.994      0.320      -0.103       0.314
# SessionID:ContrastHeterogeneity    -0.0917      0.045     -2.024      0.043      -0.180      -0.003
# SessionID:GridCoarseness           -0.0213      0.079     -0.269      0.788      -0.176       0.134
# ===================================================================================================
#
# Results for Subject 4 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                 0.02830
# Time:                        11:48:43   Log-Likelihood:                -3979.1
# converged:                       True   LL-Null:                       -4095.0
# Covariance Type:            nonrobust   LLR p-value:                 4.427e-48
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           0.7718      0.425      1.818      0.069      -0.060       1.604
# ContrastHeterogeneity               0.0662      0.166      0.399      0.690      -0.259       0.391
# GridCoarseness                     -0.6491      0.328     -1.980      0.048      -1.291      -0.007
# SessionID                           0.3190      0.086      3.691      0.000       0.150       0.488
# SessionID:ContrastHeterogeneity    -0.1907      0.034     -5.658      0.000      -0.257      -0.125
# SessionID:GridCoarseness           -0.1221      0.066     -1.843      0.065      -0.252       0.008
# ===================================================================================================
#
# Results for Subject 5 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1737
# Time:                        11:48:44   Log-Likelihood:                -2762.1
# converged:                       True   LL-Null:                       -3342.9
# Covariance Type:            nonrobust   LLR p-value:                5.956e-249
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           3.0644      0.532      5.756      0.000       2.021       4.108
# ContrastHeterogeneity              -1.8674      0.223     -8.358      0.000      -2.305      -1.429
# GridCoarseness                     -0.9733      0.396     -2.457      0.014      -1.750      -0.197
# SessionID                           0.3373      0.113      2.985      0.003       0.116       0.559
# SessionID:ContrastHeterogeneity    -0.3289      0.050     -6.576      0.000      -0.427      -0.231
# SessionID:GridCoarseness           -0.0340      0.083     -0.412      0.681      -0.196       0.128
# ===================================================================================================
#
# Results for Subject 6 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1084
# Time:                        11:48:44   Log-Likelihood:                -3270.9
# converged:                       True   LL-Null:                       -3668.6
# Covariance Type:            nonrobust   LLR p-value:                1.133e-169
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           3.7755      0.497      7.590      0.000       2.801       4.750
# ContrastHeterogeneity              -1.8146      0.198     -9.175      0.000      -2.202      -1.427
# GridCoarseness                     -1.7175      0.371     -4.624      0.000      -2.446      -0.990
# SessionID                           0.0762      0.101      0.753      0.451      -0.122       0.275
# SessionID:ContrastHeterogeneity    -0.1114      0.041     -2.731      0.006      -0.191      -0.031
# SessionID:GridCoarseness            0.0332      0.075      0.441      0.659      -0.114       0.181
# ===================================================================================================
#
# Results for Subject 7 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1555
# Time:                        11:48:44   Log-Likelihood:                -2777.5
# converged:                       True   LL-Null:                       -3289.1
# Covariance Type:            nonrobust   LLR p-value:                5.706e-219
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           4.5432      0.549      8.269      0.000       3.466       5.620
# ContrastHeterogeneity              -1.8955      0.226     -8.388      0.000      -2.338      -1.453
# GridCoarseness                     -1.9756      0.405     -4.879      0.000      -2.769      -1.182
# SessionID                           0.0100      0.113      0.089      0.929      -0.211       0.231
# SessionID:ContrastHeterogeneity    -0.2644      0.049     -5.424      0.000      -0.360      -0.169
# SessionID:GridCoarseness            0.1632      0.083      1.974      0.048       0.001       0.325
# ===================================================================================================
#
# Results for Subject 8 across all sessions:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Correct   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5994
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 12 Jun 2024   Pseudo R-squ.:                  0.1347
# Time:                        11:48:44   Log-Likelihood:                -3062.9
# converged:                       True   LL-Null:                       -3539.6
# Covariance Type:            nonrobust   LLR p-value:                7.482e-204
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           3.7686      0.506      7.441      0.000       2.776       4.761
# ContrastHeterogeneity              -1.4599      0.204     -7.156      0.000      -1.860      -1.060
# GridCoarseness                     -1.8220      0.378     -4.814      0.000      -2.564      -1.080
# SessionID                           0.0363      0.105      0.346      0.729      -0.169       0.242
# SessionID:ContrastHeterogeneity    -0.2852      0.044     -6.446      0.000      -0.372      -0.199
# SessionID:GridCoarseness            0.1627      0.078      2.086      0.037       0.010       0.316
# ===================================================================================================
